# %%
#!/usr/bin/env python
"""Dice Roller

Uses standard dice notation to roll some dice."""
import re
import random

def parse(d):
    dice, dtype_mod = d.split('d')
    
    dnum = 1
    dtype = 6
    mod = 0
    
    if dtype_mod:
        if '-' in dtype_mod:
            dtype, mod = dtype_mod.split('-')
            mod = -1 * int(mod)
        elif '+' in dtype_mod:
            dtype, mod = dtype_mod.split('+')
            mod = int(mod)
        else:
            dtype = dtype_mod
    if not dtype: dtype = 6
    if not mod: mod = 0
    
    return (int(dice), int(dtype), int(mod))

def roll(a, b):
    rolls = []
    t = 0
    
    for i in range(a):
        rolls.append(random.randint(1,b))
        t += int(rolls[i])
        print(('Roll number %d is %s, totaling %d') % (i+1, rolls[i], t))
    return(int(t))

random.seed()
notation = ""

while True:
    notation = input('Please input dice notation or q to quit: ')
    
    if notation == "q":
        raise SystemExit
    else:
        print(notation)
        
        numbers = parse(notation)
        (dice, dtype, mod) = numbers
        
        total = roll(dice, dtype)
        total += mod
        
        print('Total modified by %d' % mod)
        print('Your total is %d' % total)
# Out:
# Please input dice notation or q to quit: 3d6
# 3d6
# Roll number 1 is 4, totaling 4
# Roll number 2 is 3, totaling 7
# Roll number 3 is 5, totaling 12
# Total modified by 0
# Your total is 12
# Please input dice notation or q to quit: 3d6+6
# 3d6+6
# Roll number 1 is 6, totaling 6
# Roll number 2 is 5, totaling 11
# Roll number 3 is 5, totaling 16
# Total modified by 6
# Your total is 22
# Please input dice notation or q to quit: 1d100
# 1d100
# Roll number 1 is 24, totaling 24
# Total modified by 0
# Your total is 24
# Please input dice notation or q to quit: 11d10-10
# 11d10-10
# Roll number 1 is 4, totaling 4
# Roll number 2 is 8, totaling 12
# Roll number 3 is 1, totaling 13
# Roll number 4 is 3, totaling 16
# Roll number 5 is 9, totaling 25
# Roll number 6 is 10, totaling 35
# Roll number 7 is 9, totaling 44
# Roll number 8 is 3, totaling 47
# Roll number 9 is 8, totaling 55
# Roll number 10 is 9, totaling 64
# Roll number 11 is 3, totaling 67
# Total modified by -10
# ...

# %% [markdown]
# #Some example output#
#
# **A common stat roll**
# >Please input dice notation or q to quit: 3d6 <br>
# >3d6 <br>
# >Roll number 1 is 4, totaling 4 <br>
# >Roll number 2 is 3, totaling 7 <br>
# >Roll number 3 is 5, totaling 12 <br>
# >Total modified by 0 <br>
# >Your total is 12 <br>
#
# **Another common stat roll (heroic)**
# >Please input dice notation or q to quit: 3d6+6 <br>
# >3d6+6 <br>
# >Roll number 1 is 6, totaling 6 <br>
# >Roll number 2 is 5, totaling 11 <br>
# >Roll number 3 is 5, totaling 16 <br>
# >Total modified by 6 <br>
# >Your total is 22 <br>
#
# **A flat percentile roll**
# >Please input dice notation or q to quit: 1d100 <br>
# >1d100 <br>
# >Roll number 1 is 24, totaling 24 <br>
# >Total modified by 0 <br>
# >Your total is 24 <br>
#
# **A Bell curve for percentile**
# >Please input dice notation or q to quit: 11d10-10 <br>
# >11d10-10 <br>
# >Roll number 1 is 4, totaling 4 <br>
# >Roll number 2 is 8, totaling 12 <br>
# >Roll number 3 is 1, totaling 13 <br>
# >Roll number 4 is 3, totaling 16 <br>
# >Roll number 5 is 9, totaling 25 <br>
# >Roll number 6 is 10, totaling 35 <br>
# >Roll number 7 is 9, totaling 44 <br>
# >Roll number 8 is 3, totaling 47 <br>
# >Roll number 9 is 8, totaling 55 <br>
# >Roll number 10 is 9, totaling 64 <br>
# >Roll number 11 is 3, totaling 67 <br>
# >Total modified by -10 <br>
# >Your total is 57 <br>
